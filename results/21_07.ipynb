# %% [markdown]
# ###  Index
# - [08.07](#08.07)
# - [23.07](#23.07)

# %% [markdown]
# ###  02.07
# #### Representation of the 2. order transition probability

# %%
hm_test

# %% [markdown]
# #### Prediction error: can't reproduce 2. plot in the email
#
# - I might need to try MAE or RMSE instead

# %%
heatmap

# %% [markdown]
# #### Rough comparison between pred error and pers error
#
# - binned into 10 classes

# %%
@df df2 scatter()

# %% [markdown]
# #### pred & pers comparison by MAE
# - in Class 3 to 6 pred more accurate than pers

# %%
groupedbar()

# %% [markdown]
# ### 08.07
# #### partial autocorrelation

# %%
acfs

# %% [markdown]
# #### transition

# %%
hm_test

# %% [markdown]
# #### mn ± sd

# %%
hists12

# %%
hists34

# %%
mn_sd

# %%
mns
sds

# %% [markdown]
# #### MAE & RMSE

# %%
err2

# %%
errs

# %% [markdown]
# ### 23.07

# %% [markdown]
# #### CMF change VS prediction error
# - pers has highest slope: prediction deviation is larger than the other two predction approaches
# - pred_b (pred from prev pred) has smallest deviation

# %%
Fig. 1

# %% [markdown]
# #### Inference from neighbors
#
# - shift to 8 directions by 0.1° lon/lat
# - correlation of central to neighbors at previous time step (-15 min)
# - west cell has highest corr. coef.

# %%
Fig. 2

# %% [markdown]
# #### Performance

# %%
Fig. 3

# %%
Fig. 5

# %% [markdown]
# #### BSRN measurement
# - [x] tried looking at ShortWave Downwelling radiation in Payerne, CH, Jul.2020
# - [ ] assess variability within 10 min (?)

# %%
Fig. 5

# %%
Fig. 6

# %% [markdown]
# #### Misc
# - take 2 days in Sept. off ? to visit a friend in Denmark
#     - 03.(Fri.) & 06.(Mo.) Sept ?
